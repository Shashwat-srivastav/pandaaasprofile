# %%
# import pandas as pd
# url1=r"C:\Users\Shashwat\Desktop\diabetes.csv"
# df=pd.read_csv(url1)
# df
# !pip install pandas-profiling

# from pandas_profiling import ProfileReport
# profile=ProfileReport(df,explorative=True)
# profile.to_file('report.html')
# df

# %%
# dfd=dfd[dfd['condition'].isin(['Diabetes, Type 1','Diabetes, Type 2'])]
# dfdt=dfd[dfd['rating']>6]
# # dfdt=dfd.set_index('condition')
# # dfdt.head(50)
# # dft.loc['Diabetes, Type 1']
import matplotlib.pyplot as plt

# # dfdt['rating'].head(40).plot(kind='bar')
# # dfdt.info()
# dfdt
import pandas as pd
# !pip install pandas-profiling
from pandas_profiling import ProfileReport

df=pd.read_csv(r"C:\Users\Shashwat\Downloads\archive (1)\drugsComTest_raw.csv")
dfd=df[df['condition'].isin(['Diabetes, Type 1','Diabetes, Type 2'])]
dft=pd.read_csv(r"C:\Users\Shashwat\Downloads\archive (1)\drugsComTrain_raw.csv")
dft=dft[dft['condition'].isin(['Diabetes, Type 1','Diabetes, Type 2'])]
dftr=dfd.merge(dft,how='outer')
final=dftr.drop(columns=['date','usefulCount','uniqueID'])
final.set_index('condition')
final.info()
final.head(50)
type1=final[final['condition'].isin(['Diabetes, Type 1'])].drop_duplicates()
type2=final[final['condition'].isin(['Diabetes, Type 2'])].drop_duplicates()
pd.concat([type1,type2])
type1.info()
type2.info()

type2report=ProfileReport(type2.drop(columns=['condition','review']),explorative=True)
type2report.to_file('type2report.html')
# Out:
# ...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3547 entries, 0 to 3546
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   drugName   3547 non-null   object
#  1   condition  3547 non-null   object
#  2   review     3547 non-null   object
#  3   rating     3547 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 138.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185 entries, 1 to 3492
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   drugName   185 non-null    object
#  1   condition  185 non-null    object
#  2   review     185 non-null    object
#  3   rating     185 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 7.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3362 entries, 0 to 3546
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ...

# %%
# type1=type1.drop(columns=['review'])
type22=type2.set_index('drugName')
type22=type22.drop_duplicates()
type22=type22.groupby('drugName').agg({'rating':['mean','max','min']})

type22['rating'].head(30).plot(kind='bar')
type22.info()
type2=type2.drop_duplicates()
type2.head(25).sort_values(by=['rating'],ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Actos to Victoza
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (rating, mean)  7 non-null      float64
#  1   (rating, max)   7 non-null      int64
#  2   (rating, min)   7 non-null      int64
# dtypes: float64(1), int64(2)
# memory usage: 224.0+ bytes
#                        drugName         condition  rating
# 10                      Exubera  Diabetes, Type 2      10
# 16                 Pioglitazone  Diabetes, Type 2      10
# 8                   Dulaglutide  Diabetes, Type 2      10
# 15  Empagliflozin / linagliptin  Diabetes, Type 2       9
# 3                   Liraglutide  Diabetes, Type 2       9
# 14                   Glucophage  Diabetes, Type 2       9
# 13                  Dulaglutide  Diabetes, Type 2       9
# 28                      Farxiga  Diabetes, Type 2       9
# 4                     Glyburide  Diabetes, Type 2       9
# ...

# %%
type11=type1.set_index('drugName')
type11=type11.drop_duplicates()
type11=type11.groupby('drugName').agg({'rating':['mean','max','min']})
type11.head(25).plot(kind='bar')

type11.info()
type1=type1.drop_duplicates()
type1.head(25).sort_values(by=['rating'],ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Afrezza to Tresiba
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (rating, mean)  7 non-null      float64
#  1   (rating, max)   7 non-null      int64
#  2   (rating, min)   7 non-null      int64
# dtypes: float64(1), int64(2)
# memory usage: 224.0+ bytes
#                              drugName         condition  rating
# 1                             Afrezza  Diabetes, Type 1      10
# 215  Insulin inhalation, rapid acting  Diabetes, Type 1      10
# 633                           Tresiba  Diabetes, Type 1      10
# 504                  Insulin degludec  Diabetes, Type 1      10
# 499    Humulin R U-500 (Concentrated)  Diabetes, Type 1      10
# 716               NovoLog Mix 70 / 30  Diabetes, Type 1      10
# 95                          Humulin N  Diabetes, Type 1      10
# 397             Sandostatin LAR Depot  Diabetes, Type 1       9
# ...
