# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashwat-srivastav/pandaaasprofile/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/sample_data/california_housing_train.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.nunique()
# Out:
# longitude               827
# latitude                840
# housing_median_age       52
# total_rooms            5533
# total_bedrooms         1848
# population             3683
# households             1740
# median_income         11175
# median_house_value     3694
# dtype: int64

# %%
df.value_counts()
# Out:
# longitude  latitude  housing_median_age  total_rooms  total_bedrooms  population  households  median_income  median_house_value
# -124.35    40.54     52.0                1820.0       300.0           806.0       270.0       3.0147         94600.0               1
# -118.18    33.88     44.0                1308.0       267.0           783.0       237.0       4.7361         167700.0              1
#            33.83     44.0                1497.0       277.0           542.0       274.0       5.0052         321800.0              1
#                      45.0                1535.0       274.0           591.0       276.0       4.2411         371700.0              1
#                      52.0                2569.0       484.0           1030.0      451.0       4.1301         268400.0              1
#                                                                                                                                   ..
# ...

# %%
df.shape
# Out:
# (17000, 9)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
col=df.columns

# %%
from pandas.plotting import boxplot
for i in col:
  boxplot(df[i])
  print(i)
  plt.show()
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value

# %%
df["total_bedrooms"].info()
df["total_bedrooms"].describe()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 17000 entries, 0 to 16999
# Series name: total_bedrooms
# Non-Null Count  Dtype
# --------------  -----
# 17000 non-null  float64
# dtypes: float64(1)
# memory usage: 265.6 KB
# count    17000.000000
# mean       539.410824
# std        421.499452
# min          1.000000
# 25%        297.000000
# 50%        434.000000
# 75%        648.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %% [markdown]
# # Removing Outliers

# %%
df.quantile([0.25,0.75])
# df.quantile(0.25)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0.25    -121.79     33.93                18.0      1462.00          297.00
# 0.75    -118.00     37.72                37.0      3151.25          648.25
#
#       population  households  median_income  median_house_value
# 0.25       790.0      282.00       2.566375            119400.0
# 0.75      1721.0      605.25       4.767000            265000.0

# %%
for i in col:
  iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
  iqr=abs(iqr)
  lf=df[i].quantile(0.25)-1.5*(iqr)
  uf=df[i].quantile(0.75)+1.5*(iqr)
  df=df[(df[i]<uf)&(df[i]>=lf)]
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# 5        -114.58     33.63                29.0       1387.0           236.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
from pandas.plotting import boxplot
for i in col:
  boxplot(df[i])
  print(i)
  plt.show()
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value

# %%
df.drop_duplicates()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# 5        -114.58     33.63                29.0       1387.0           236.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
import seaborn as sb
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923320           -0.089977    -0.009356
# latitude            -0.923320  1.000000           -0.011313     0.010077
# housing_median_age  -0.089977 -0.011313            1.000000    -0.279166
# total_rooms         -0.009356  0.010077           -0.279166     1.000000
# total_bedrooms       0.031875 -0.043135           -0.211483     0.881062
# population           0.118699 -0.148252           -0.174346     0.757829
# households           0.032000 -0.069137           -0.178527     0.873291
# median_income        0.001920 -0.094829           -0.168921     0.298422
# median_house_value  -0.035017 -0.165806            0.089139     0.199359
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.031875    0.118699    0.032000       0.001920
# latitude                 -0.043135   -0.148252   -0.069137      -0.094829
# ...

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
for i in col:
  df[i].plot(kind="hist",x=i)
  plt.show()
  print(i)
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value

# %%
for i in col:
  df[i].plot(kind="kde",x=i)
  plt.show()
  print(i)
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value

# %%
# df=df.drop(columns=["latitude","longitude"])

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
#
#    population  households  median_income  median_house_value
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0

# %%
cols=df.columns
for i in cols:
  df[i].plot(kind="kde")
  plt.show()
  print(i)
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value

# %%
X=df.drop(columns=["median_house_value"])
y=df["median_house_value"]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=42)
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
#
#    population  households  median_income
# 2       333.0       117.0         1.6509
# 3       515.0       226.0         3.1917
# 4       624.0       262.0         1.9250
# 5       671.0       239.0         3.3438
# 6      1841.0       633.0         2.6768

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr=lr.fit(X_train,y_train)

# %%
from sklearn.metrics import accuracy_score
lr.score(X_test,y_test)

lr.predict(X_test)
# accuracy_score(y_test,lr.predict(X_test))
# Out:
# array([249761.01933398, 172140.02751167,  75151.01964337, ...,
#        316719.96999251, 265370.49353154, 198912.83022613])

# %%
df2=pd.read_csv("/content/sample_data/california_housing_test.csv")
df2_x=df2.drop(columns=["median_house_value"])
df2_y=df2["median_house_value"]

# lr.predict(df2_x)

# %%
# accuracy_score(df2_y,lr.predict(df2_x))
from sklearn.metrics import r2_score
r2_score(y_test, lr.predict(X_test)),r2_score(df2_y,lr.predict(df2_x))
# Out:
# (0.6158152707385923, 0.5875237270106658)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regre=RandomForestRegressor()
regre.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
regre.score(X_test,y_test),regre.score(df2_x,df2_y)
# df_show=pd.DataFrame(df_show)
df_show=[]
df_show=pd.DataFrame(df_show)

# %%
df_show["predicted"]=pd.DataFrame(regre.predict(df2_x))
df_show["actual"]=df2_y
df_show
regre.fit(df2_x,df2_y)
# Out:
# RandomForestRegressor()

# %%
regre.score(X_train,y_train),regre.score(X_test,y_test)
# Out:
# (0.7257345571742715, 0.698441872848907)

# %%
plt.scatter(x=df_show["actual"],y=df_show["predicted"],s=1,linewidths=1)

plt.show()

# %%
df_show["predicted"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
boxplot(df_show["predicted"])
# Out:
# <Axes: >
