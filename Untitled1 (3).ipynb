# %%
import pandas as pd
url1=r"C:\Users\Shashwat\Desktop\diabetes.csv"
df=pd.read_csv(r"C:\Users\Shashwat\Downloads\archive (1)\drugsComTrain_raw.csv")
df=df[df['condition'].isin(['Diabetes, Type 1','Diabetes, Type 2'])]
df=df.drop(columns=['review','date','usefulCount','uniqueID'])
df.drop_duplicates()
type1=df[df['condition'].isin(['Diabetes, Type 1'])]
# type1=type1.set_index('drugName')
type1=type1.drop(columns=['condition'])
type1=type1.drop_duplicates().set_index('rating')

# type1.groupby(by='drugName').agg({'rating':['mean','max','min']})
# type1['drugName']=type1['drugName'].drop_duplicates().values_
# type1['drugName'].values_counts()
pd.get_dummies(type1,columns=['drugName'],drop_first=True)
type1['drugName'].value_counts()
# !pip install pandas-profiling
dfshi=pd.read_csv(r"C:\Users\Shashwat\Downloads\Medicare Prescription Drugs Claims.csv\data.csv")
dfshi

# from pandas_profiling import ProfileReport
# profile=ProfileReport(df,explorative=True)
# profile.to_file('report.html')
# df
# Out:
#          Beneficiary_Age_Category_Code  RxNorm_Concept_Unique_Identifier  \
# 0                                    1                               NaN
# 1                                    1                               NaN
# 2                                    1                               NaN
# 3                                    1                               NaN
# 4                                    1                               NaN
# ...                                ...                               ...
# 1048570                              6                            3743.0
# 1048571                              6                            3743.0
# 1048572                              6                            3743.0
# 1048573                              6                            3743.0
# 1048574                              6                            3743.0
#
#         Drug_Major_Class Drug_Class  Drug_Type_Class  Plan_Type  \
# ...

# %%
# dfd=dfd[dfd['condition'].isin(['Diabetes, Type 1','Diabetes, Type 2'])]
# dfdt=dfd[dfd['rating']>6]
# # dfdt=dfd.set_index('condition')
# # dfdt.head(50)
# # dft.loc['Diabetes, Type 1']
import matplotlib.pyplot as plt

# # dfdt['rating'].head(40).plot(kind='bar')
# # dfdt.info()
# dfdt
import pandas as pd
# !pip install pandas-profiling
from pandas_profiling import ProfileReport

df=pd.read_csv(r"C:\Users\Shashwat\Downloads\archive (1)\drugsComTest_raw.csv")
dfd=df[df['condition'].isin(['Diabetes, Type 1','Diabetes, Type 2'])]
dft=pd.read_csv(r"C:\Users\Shashwat\Downloads\archive (1)\drugsComTrain_raw.csv")
dft=dft[dft['condition'].isin(['Diabetes, Type 1','Diabetes, Type 2'])]
dftr=dfd.merge(dft,how='outer')
final=dftr.drop(columns=['date','usefulCount','uniqueID'])
final.set_index('condition')
final.info()
final.head(50)
type1=final[final['condition'].isin(['Diabetes, Type 1'])].drop_duplicates()
type2=final[final['condition'].isin(['Diabetes, Type 2'])].drop_duplicates()
type1=type1.drop(columns=['review'])
type2=type2.drop(columns=['review'])
type1=type1.drop_duplicates()
type2=type2.drop_duplicates()
# pd.concat([type1,type2])
type1.info()
type2.info()

# type2report=ProfileReport(type2.drop(columns=['condition','review']),explorative=True)
# type2report.to_file('type2report.html')
# Out:
# ...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3547 entries, 0 to 3546
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   drugName   3547 non-null   object
#  1   condition  3547 non-null   object
#  2   review     3547 non-null   object
#  3   rating     3547 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 138.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 1 to 3492
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   drugName   85 non-null     object
#  1   condition  85 non-null     object
#  2   rating     85 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 481 entries, 0 to 3534
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...

# %%
# type1=type1.drop(columns=['review'])
# type22=type2.set_index('drugName')
# type22=type22.drop_duplicates()
# type22=type22.groupby('drugName').agg({'rating':['mean','max','min']})

# type22['rating'].head(30).plot(kind='bar')
# type22.info()
type2=type2.drop_duplicates()
type2.head(25).sort_values(by=['rating'],ascending=False)
type2.info()
type2['drugName'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 481 entries, 0 to 3534
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   drugName   481 non-null    object
#  1   condition  481 non-null    object
#  2   rating     481 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 15.0+ KB
# Actos                         10
# Pioglitazone                  10
# Empagliflozin                 10
# Sitagliptin                   10
# Glipizide                     10
#                               ..
# Glimepiride / pioglitazone     1
# Pramlintide                    1
# Nateglinide                    1
# Apidra                         1
# Kazano                         1
# Name: drugName, Length: 97, dtype: int64

# %%
type11=type1.set_index('drugName')
type11=type11.drop_duplicates()
type11=type11.groupby('drugName').agg({'rating':['mean','max','min']})
type11.head(30).plot(kind='bar')

# type11.info()
type1=type1.drop_duplicates()
type1.sort_values(by=['rating'],ascending=False)
# type1=pd.get_dummies(type1,columns=["drugName",'condition'])
# type1.head(50)
# type1['drugName']
# type1
#
# Out:
#                             drugName         condition  rating
# 1                            Afrezza  Diabetes, Type 1      10
# 499   Humulin R U-500 (Concentrated)  Diabetes, Type 1      10
# 1019                     Liraglutide  Diabetes, Type 1      10
# 1424                         Exubera  Diabetes, Type 1      10
# 1440                    SymlinPen 60  Diabetes, Type 1      10
# ...                              ...               ...     ...
# 204                          Afrezza  Diabetes, Type 1       1
# 87                           Tresiba  Diabetes, Type 1       1
# 417                 Insulin degludec  Diabetes, Type 1       1
# 2570                 Lantus Solostar  Diabetes, Type 1       1
# 2351                          Toujeo  Diabetes, Type 1       1
#
# [85 rows x 3 columns]

# %%
# pd.get_dummies(type1,columns=['drugName'],drop_first=True)
# X=type1[['drugName','rating']]
# y=type1[['drugName','rating']]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(type1.drop(columns=['rating']),type1,test_size=0.2,random_state=10)
# X_train
# X_test

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ohe=OneHotEncoder()

transformer=ColumnTransformer(transformers=[('dN',ohe,['drugName']),('cO',ohe,['condition'])],remainder='passthrough')
X_train=transformer.fit_transform(X_train)
y_train=transformer.fit_transform(y_train)

# %%
X_train.toarray()
X_train.shape,X_test.shape
# y_train.shape
# Out:
# ((68, 34), (17, 2))

# %%
# from sklearn.pipeline import Pipeline
# from category_encoders.target_encoder import TargetEncoder
# !pip install xgboost
# !pip install optuna

import xgboost as xgb
import sklearn
import optuna
from xgboost import XGBClassifier
# from validation_train import train

# XGBoost_model = train(X_train, y_train, X_test, y_test, balanced='balanced', method='XGBoost')
parameters = {
        'learning_rate': 0.3,
        'max_depth': 3,
        'lambda': 0.05
}

# %%
model = xgb.XGBClassifier(**parameters)
start = timeit.default_timer()
XGBoost_model = model.fit(X_train,y_train)
stop = timeit.default_timer()
stop - start
y_prob = XGBoost_model.predict(X_test)
auc_logloss_ks(y_test, y_prob)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [551], in <cell line: 3>()
#       1 model = xgb.XGBClassifier(**parameters)
#       2 start = timeit.default_timer()
# ----> 3 XGBoost_model = model.fit(X_train,y_train)
#       4 stop = timeit.default_timer()
#       5 stop - start
#
# File ~\anaconda3\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\lib\site-packages\xgboost\sklearn.py:1438, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1434     self.n_classes_ = len(self.classes_)
# ...

# %%
# !pip install validation_train 
import validation_train
# Out:
# ERROR: Could not find a version that satisfies the requirement validation_train (from versions: none)
# ERROR: No matching distribution found for validation_train
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [527], in <cell line: 2>()
#       1 get_ipython().system('pip install validation_train')
# ----> 2 import validation_train
#
# ModuleNotFoundError: No module named 'validation_train'

# %%
# from sklearn.neighbors import KNeighborsClassifier
# knn=KNeighborsClassifier(n_neighbors=10)
# knn.fit(X_train,y_train)

# %%
# from sklearn import preprocessing
# lb = preprocessing.LabelBinarizer()
# # y_train=lb.fit_transform(y_train)
# # X_train=lb.fit_transform(X_train)
# # X_test=lb.fit_transform(X_test)
# # y_test=lb.fit_transform(y_test)
# from sklearn.neighbors import KNeighborsClassifier
# knn=KNeighborsClassifier(n_neighbors=10)
# knn.fit(X_train.toarray(),y_train.toarray())


# knn.predict(X_train)
# knn.score(X_train,y_train)
